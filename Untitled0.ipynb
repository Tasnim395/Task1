# %% [markdown]
# <a href="https://colab.research.google.com/github/Tasnim395/Task1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = 10==10
s1 = 2>7
print(s)
print(s1)
# Out:
# True
# False

# %%
 print("kkkkk")
# Out:
# kkkkk

# %%
a= "hi"
b= 2
c= "toro"
print(a*b)
print(a+c)
# Out:
# hihi
# hitoro

# %%
data = "apple,banana,cat"
fruits=data.split(",")
print(fruits)
# Out:
# ['apple', 'banana', 'cat']

# %%
cats= "kitty + toros"
kittens = cats.replace("kitty","kittens")
print(kittens)
# Out:
# kittens + toros
